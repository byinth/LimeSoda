# %%
from ast import literal_eval
import json
import os
from typing import List

import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Configs

# %%
HAM_CSV = "raw/data_v1.csv"
WOHAM_CSV = "raw/data_notagword_v1.csv"

VAL_FROM_TRAIN_RATIO = 0.10

X_COLUMN = "text"
TOKEN_TAG_COLUMN = "tag_by_word"
Y_COLUMN = "tags"
RANDOM_SEED = 42

# %% [markdown]
# ## Read data

# %%
w_ham_converters = {
    "text": literal_eval,
    "tag_by_word": literal_eval
}

w_ham_df = pd.read_csv(HAM_CSV, converters=w_ham_converters)
print(len(w_ham_df))
w_ham_df.head()
# Out:
# 4141
#                                                 text  \
# 0  [ประเทศจีน, ชอบ, ปลอม, เอา, ยาง, รถ, ไป, ทำ, ไ...
# 1  [ประกาศ, กฎ, อัยการศึก, ปิด, การ, เข้า, ออก, ท...
# 2  [ประโยชน์, มาก, ก็, ใช่, ว่า, จะ, ไม่, มี, โทษ...
# 3  [มั่นใจ, กระซิบ, หู, หนู, พระพิฆเนศ, ไม่, ติด,...
# 4  [พวก, ที่, เชื่อ, ว่า, คน, ไม่, ป่วย, ไม่, ต้อ...
#
#                                          tag_by_word       tags
# 0  [I-Influencer, Fb-Refer, Fb-Refer, Fb-Refer, F...  Fake News
# 1  [T-Clickbait, T-Clickbait, T-Clickbait, , , , ...   Undefine
# 2  [, , , , , , , , , , , M-Convincing, M-Convinc...   Undefine
# 3  [T-Clickbait, T-Clickbait, T-Clickbait, T-Clic...  Fake News
# 4  [, , , , , , , , , , , , , , , , , , , , , , ,...   Undefine

# %%
wo_ham_converters = {
    "title": lambda x: literal_eval(x) if x else [],
    "detail": lambda x: literal_eval(x) if x else []
}
wo_ham_df = pd.read_csv(WOHAM_CSV, converters=wo_ham_converters)
print(len(wo_ham_df))


def get_text(_title: List[str], _detail: List[str]) -> List[str]:
    if _detail and not _title:
        return _detail
    elif _title and not _detail:
        return title
    return [*_title, '|', '|', '|', *_detail]

wo_ham_df["text"] = wo_ham_df.apply(lambda x: get_text(x.title, x.detail), axis=1)
wo_ham_df.head()
# Out:
# 3050
#                                                title  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [รู้, ไว้, มี, ประโยชน์, !, , , ไม่, อยาก, เป็...
#
#                                               detail       tags  \
# 0  [พี่, สาว, คน, ข้าง, บ้าน, เป็น, มะเร็ง, ต่อม,...  Fake News
# 1  [กิน, แทน, ข้าว, หนุ่ม, เวียดนาม, ปวด, ท้อง, 2...  Fake News
# 2  [", ต้น, ป่าช้า, เหงา, ", สมุนไพร, ไทย, ดัง, ไ...  Fake News
# 3  [ผง, ชู@@, รส, นี่, ก็, สาร, พิษ, ก่อ, เกิด, โ...  Fake News
# 4  [ไม่, อยาก, เป็น, นิ่ว, , , ต้อง, หลีกเลี่ยง, ...  Fake News
#
#                                                 text
# 0  [พี่, สาว, คน, ข้าง, บ้าน, เป็น, มะเร็ง, ต่อม,...
# 1  [กิน, แทน, ข้าว, หนุ่ม, เวียดนาม, ปวด, ท้อง, 2...
# 2  [", ต้น, ป่าช้า, เหงา, ", สมุนไพร, ไทย, ดัง, ไ...
# 3  [ผง, ชู@@, รส, นี่, ก็, สาร, พิษ, ก่อ, เกิด, โ...
# 4  [รู้, ไว้, มี, ประโยชน์, !, , , ไม่, อยาก, เป็...

# %%
print("Total sampling: %d"%(len(w_ham_df) + len(wo_ham_df)))
# Out:
# Total sampling: 7191

# %% [markdown]
# ## Splitting

# %%
X, Y = wo_ham_df[X_COLUMN], wo_ham_df[Y_COLUMN]

# %%
x_train, x_val, y_train, y_val = train_test_split(
    X, Y, test_size=VAL_FROM_TRAIN_RATIO,
    stratify=Y, random_state=RANDOM_SEED
)
print(len(x_train), len(y_train))
print(len(x_val), len(y_val))
# Out:
# 2745 2745
# 305 305

# %%
x_test, x_tags_test, y_test = w_ham_df[X_COLUMN], w_ham_df[TOKEN_TAG_COLUMN], w_ham_df[Y_COLUMN]
print(len(x_test), len(x_tags_test), len(y_test))
# Out:
# 4141 4141 4141

# %% [markdown]
# ### Remove train/test overlap

# %%
train_texts = ["".join(x) for x in X]

nondup_x_test = []
nondup_x_tags_test = []
nondup_y_test = []

n_leak = 0
for x, tags, y in zip(x_test, x_tags_test, y_test):
    if "".join(x) in train_texts:
        n_leak += 1
        print(n_leak, "".join(x))
        continue
    nondup_x_test.append(x)
    nondup_x_tags_test.append(tags)
    nondup_y_test.append(y)
# Out:
# 1 ประเทศจีนชอบปลอมเอายางรถไปทำไข่มุกค่ะ
# 2 มันคือน้ำศักดิ์สิทธิ์ไว้รักษาคนป่วยเป็นมะเร็ง
# 3 พวกคุณเข้าใจผิดกันไปใหญ่แล้วสิ่งที่พวกคุณเห็นมันไม่ใช่หน้ากากอนามัยแต่มันคือแป้ง..
# 4 น่ากลัวมากไข่มุกที่มีในน้ำถ้วยมันย่อยยากบางคนไม่ย่อยเลยคาในท้องต้องผ่าตัดออกมาระวังด้วย
# 5 นั่งฟังเเม่พูดว่าให้กินน้ำอุ่นผสมมะนาวช่วยต้านโควิดอันนี้เรื่องจริงมั้ย?!
# 6 เบียร์15กระป๋องทำลายเชื้อโควิดได้ครีบ
# 7 แม่ผัวบอกไข่มุกจีนทำจากยางรถยนต์เลิกกินเลยค่ะ555+
# 8 น้ำศักดิ์สิทธิ์ครับตักใส่ขวดกลับไปกินเป็นยารักษาโรคได้เลย
# 9 มันไม่หน้ากากอนามัยมันคือกระดาษเค้าเข้าใจผิด
# 10 ผลิตภัณฑ์ดีคอนแทคได้รับความไว้วางใจจากลูกค้า
# 11 ฟื้นฟูการได้ยิน100%โดยไม่มีการผ่าตัดให้คุณใช้ชีวิตโดยไม่ต้องพึ่งเครื่องช่วยฟังไม่ก่อให้เกิดการแพ้และปลอดภัยสำหรับทุกวัยจากธรรมชาติ100%
# 12 ภาพที่เห็นไม่ใช่หน้ากากอนามัยแต่เป็นผ้าอนามัยตำรวจออสซี่เข้าใจผิดแล้ว
# 13 มันคือสมุนไพรรักษามะเร็ง
# 14 มันไม่ย่อยชาไข่มุก
# 15 มีสมุนไพรรักษามะเร็งมั้ยคะ
# 16 มีสมุนไพรรักษามะเร็งมั้ยครับ
# 17 ไม่เคี้ยวรึป่าวหรือว่าไข่มุกทำจากยางรถยนต์
# 18 ยังสรุปไม่ได้ว่าหนานเฉาเหว่ยรักษาโรคเบาหวานได้
# 19 ยาสมุนไพรรักษามะเร็ง
# 20 เราค้นพบบ่นน้ำศักดิ์สิทธิ์55555มีชมพูรักษาได้ทุกโรค55555
# 21 โรคตาที่ดีคอนแทคเข้าไปฟื้นฟูเร่งด่วน
# 22 โรคที่ดีคอนแทคเข้าไปฟื้นฟูเร่งด่วน
# 23 เรื่องกักตุนหน้ากากอนามัย200ล้านอันมันไม่มีการกักตุนจริงต้องมีเบื้องหลังแน่นอนที่ออกข่าวเท็จในลักษณะนี้
# 24 โรคมะเร็ง|||คือหนูได้ยินมาว่าน้ำมันกัญชารักษาโรคมะเร็งนี้จริงมั้ยคะ?แล้วที่ไหนมีแบบถูกกฎหมายแบบ
# 25 มองเห็นชัดเจนขึ้นหลังจากทานดีคอนแทค
# 26 รีบหามาปลูกไว้หนานเฉาเหว่ยสมุนไพรสรรพคุณเพียบช่วยแก้ได้หลายโรคดีต่อร่างกาย
# 27 มีน้ำมันกัญชาเพื่อรักษาโรคมะเร็งขายมั้ยครับ?
# 28 เม็ดไข่มุกทำมาจากยางในรถยนต์
# 29 น่าจะเป็นน้ำศักดิ์สิทธิ์ดื่มกินแก้โรคร้ายได้ครับ
# 30 นี่กินชาไข่มุกก็กรดไหลย้อนกำเริบทุกครั้งท้องอืดไม่ย่อยแน่นกว่าจะหาย
# 31 บอกสิครับว่าส่งรัฐมนตรีช่วยฯไปดำเนินการล่อซื้อ555หรือบอกไปเลยทุกคนเข้าใจผิดมันเป็นผ้าอนามัยไม่ใช่หน้ากากอนามัย
# 32 นั้นล่ะพากันกินไก่หลาย.ไก่เขาเร่งสารฮอร์โมนให้เปนสาวไว
# 33 น้ำศักดิ์สิทธิ์รักษาโรคดีครับ
# 34 นี้อาจจะเป็นน้ำศักดิ์สิทธิ์นะครับรักษาโรคได้
# 35 #ทุกปัญหาดีคอนแทคช่วยท่านได้#
# 36 กินไก่ทุกวันจะอ้วนกว่าเดิมนะเพราะในเนื้อไก่มีสารเร่งให้โตเร็วถ้าคนกินเข้าไปทุกวันเราก็จะโตเร็วเหมือนไก่
# 37 ของไทยไม่แพ้นอก!!'ยาเขียว'กินแทนพาราได้ถูกและดีต่อตับมากกว่าเยอะ!!
# 38 ไก่ฉีดฮอร์โมนเร่งมะเร็ง
# 39 ขนาดฉี่คนยังรักษาโรคได้ผลการวิจัยบอกฉี่เราตอนเช้าบริสุทธิ์สามารถกินได้แล้วฉี่จักจั่นสะอาดกว่าฉี่มนุษย์อีกทำไมกินไม่ได้ใครเอาไปวิจัยหรือยังฉี่จักจั่นมีพิษ
# 40 แก้ได้ทุกโรคมีหลายชื่อป่าช้าเหงาบางท่านเรียกเจียวกู่หลานแล้วไช่หรือเปล่าเจียวหลาน
# 41 ไก่มีสารเร่งโต
# 42 ขายต้นหนานเฉาเหว่ยสร้างภูมิคุ้มกันรักษาตับเลี้ยงสัตว์ต้นละ50บาทรวมส่ง.ยาดีปลูกครั้งเดียวห่างไกลโรคทั้งชาติ
# 43 ไข่มุกปลอมเลยไม่ย่อย😁
# 44 ขอเรื่องดีคอนแทคด้วยครับคนแก่ไม่ค่อยฟัง
# 45 "ต้นป่าช้าเหงา"สมุนไพรไทยดังไกลไปทั่วโลกหลังสามารถช่วยรักษาได้สารพัดโรค
# 46 ไข่มุกทานแล้วย่อยยากนะครับถ้าไม่มีคุณภาพนะครับ
# 47 เก่งเหมือนแม่!นักวิจัยยืนยันความฉลาดของลูกได้มาจากแม่ล้วนๆ
# 48 กินไก่ที่ฝังฮอร์โมนเร่งโตมาก
# 49 กินเยอะไข่มุกไม่ย่อย
# 50 ไข่มุกกินแล้วย่อยยากมาก
# 51 ไข่มุกทานมากๆไม่ย่อยนะค่ะระวังกันด้วยมันย่อยยาก
# 52 ดีคอนแทคขายแบบไหนอย่างไรราคาเท่าใดอยากรู้ค่ะ
# 53 ต้องการจะสั่งซื้อได้ที่ไหนครับดีคอนแทค
# 54 นอกจากเม็ดไข่มุกในชาที่มีข่าวว่าทำมาจากมันสำปะหลังบ้างหัวมันบ้างหรือถึงขั้นทำมาจากยางรถยนต์เก่าและรองเท้าเก่ายังมีอาหารและวัตถุดิบปลอมอย่างน้อยอีก5ชนิดต่อไปนี้ที่ถูกคิดค้นและจำหน่ายแพร่หลายในแดนมังกรเกือบทุกชนิดถูกตรวจพบก็ต่อเมื่อมีคนไม่สบายบางรายก็เสียชีวิต
# 55 ตามสากลค่ากลาง60-70%แอลกอฮอล์สามารถฆ่าเชื้อได้นะครับ..ประกาศนี้ออกมาได้อย่างไร??ส่วนค่าที่เหมาะสม68-72%(อ้างอิงFDA)..ไม่แห้งเร็วหรือช้าเกินไป..ทั้ง4สูตรผมลองคำนวนค่าแอลกอฮอล์ออกมาได้ทีี่สูตร1:79.16%สูตร2:56.36%สูตร3:66.5%สูตร4:71.25%จะเอาอย่างไรแน่ครับ..2ใน4สูตรที่แนะนำความเข้มข้นแอลกอฮอล์ไม่ผ่านตามประกาศ..มีวาระซ่อนเร้นอีกหรือไม่..เพราะเดือดร้อนต้องเทียวหา95%แอลกอฮอล์มาเป็นสารตั้งต้นความวัวไม่ทันหาย..หน้ากากอนามัยความควายเข้ามาแทรก..แอลกอฮอล์ถูมือ!!ก็ด้วยบรรดาคุณท่านช่างคิดและช่างทำกันทั้งนั้น!!
# 56 ตักน้ำศักดิ์สิทธิ์มาดื่มรักษาโรคด้วยครับ
# 57 ทุกปัญหาสายตาดีคอนแทคดูแลท่านได้
# 58 ดื่ม1แก้วก่อนนอนความจำดีขึ้นด้วยสมุนไพรโบราณ
# 59 เด็กสมัยนี้โตวัย.ชอบกินเนื้อไก่.มีสารเร่งโตในไก่555
# 60 ทานดีคอนแทคบ้าง
# 61 ทำไมรู้สึกว่ากินชาไข่มุกแล้วเหมือนมันไม่ย่อยหรือเราเคี้ยวไม่ละเอียดกลายเป็นไม่ชอบเวลาคนขายถามใส่ไข่มุกมั้ยคะเราจะบอกว่าไม่เอา
# 62 ที่ทุกคนกำลังเข้าใจว่าคนของผมกักตุน”หน้ากากอนามัย”คุณกำลังเข้าใจผิดความจริงแล้วมันคือ“หน้ากากทุเรียน”
# 63 ที่จริงแล้วที่ทางการไทยเข้าใจผิดคิดว่าเป็นหน้ากากอนามัย3.2โลนั้นแท้จริงแล้วมันคือผ้าอนามัย!!!!
# 64 เท่าที่รู้ไข่มุกก็ย่อยยากเหมือนกัน
# 65 นักข่าวเข้าใจผิดคับ..อันที่ผมถ่ายมันไม่ใช่หน้ากากอนามัย...แต่มันคือ...ผ้าปิดจมูก...😆😆นักข่าวเข้าใจผิดกันไปเอง..ลูกพี่ผมได้กล่าวไว้😎😎
# 66 ที่อเมริกาเขาเอาน้ำมันกัญชามาดื่มรักษาโรคมะเร็ง
# 67 ทุกปัญหาสายตาดูแลได้ด้วยดีคอนแทค
# 68 สุดยอดสมุนไพรรักษามะเร็ง
# 69 วันนี้ไปสีลมนะคะ..ดีคอนแทคเข้าเมือง
# 70 สุดยอดเลยจ้าดีคอนแทค
# 71 เห็นข่าวไข่มุกหลายลอบแล้วเลยไม่ซื้อกินบ่อยแล้วเดี๋ยวนี้มันย่อยยาก!
# 72 อาจารย์มัวแต่ขายดีคอนแทค
# 73 อยากกินทุเรียนแต่เป็นเบาหวาน
# 74 อยากทราบว่าน้ำมันกัญชาสกัดช่วยรักษาโรคมะเร็งหรือพากินสันได้จริงเหรอคะแล้วน้ำมันกัญชาควรใช้อย่างไรคะ
# 75 อาการดีขึ้นเพราะทานดีคอนแทค
# 76 ลูกชายก็เปนค่ะกินชาไข่มุกแก้วเดียวนอนโรงบาลหมอห้ามไม่ให้กินไข่มุกค่ะมันย่อยยากค่ะ
# 77 สนใจยาสมุนไพรรักษามะเร็งไหมค่ะเพราะพ่อเปนหมอรักษาโรคมะเร็งค่ะ
# 78 ไข้หวัด..เป็นได้ทั้งในเด็กและผู้ใหญ่แนะนำให้กลุ่มเสี่ยงไปฉีดวัคซีนเพื่อป้องกันโรคในกรณีที่เด็กป่วยด้วยโรคไข้หวัดใหญ่แนะนำให้รักษาตัวอยู่ที่บ้านจนกว่าจะหยุด"ไอ"เนื่องจากการ"ไอ"ทำให้แพร่เชื้อออกจากร่างกายและทำให้เด็กคนอื่นๆติดเชื้อได้
# 79 เลี่ยงได้ด้วยการ"ปรุงสุกกินร้อนช้อนกลางล้างมือ"นะครับ
# 80 กรมควบคุมโรค"แนะประชาชน...กินร้อนช้อนกลางล้างมือ...ดื่มน้ำและกินน้ำแข็งที่สะอาดป้องกันโรคอุจจาระร่วง"
# 81 สาธารณสุขเชียงใหม่คาดก.พ.นี้มีผู้ติดเชื้อ"ไข้หวัดใหญ่"มากขึ้น
# 82 กินร้อนช้อนกลางล้างมือยังคงใช้ได้ตลอดระมัดระวังกันนะคะ
# 83 👉รู้ให้ทันไวรัสโคโรนา👨‍⚕️รักษาสุขภาพกินร้อนช้อนกลางล้างมือ✨
# 84 รมว.สาธารณสุขรณรงค์กระตุ้นประชาชนกินร้อนช้อนกลางล้างมือและใส่หน้ากากอนามัยโดยแจกหน้ากากอนามัยและแอลกอฮอล์ล้างมือบริเวณสถานีรถไฟฟ้าสยาม
# 85 อย.พร้อมสกัดกัญชาเป็นยารักษาโรค
# 86 แจกฟรีสมุนไพรรักษามะเร็ง!!
# 87 ช็อกหนักมาก!จีนพบชาไข่มุกปลอมทำจากยางรถและหนังรองเท้าคนกินถูกหามส่งรพ.
# 88 ชาไข่มุกไงที่ทำจากยางรถยนต์และรองเท้าเก่า^^
# 89 ชาวบ้านแห่รองน้ำใต้ต้นสะตอดื่มรักษาโรค
# 90 ดีคอนแทคดีจริงๆครับ
# 91 ดวงตาดีด้วยดีคอนแทค
# 92 เคยอ่านนะว่าหนานเฉาเว่ยเขาไม่ให้กินติดต่อกันเพราะมันมีผลต่อไตแต่ส่วนมากคนกินไม่ได้ศึกษาถึงผลกระทบที่จะตามมาแรกๆเลยเขาให้กินแค่วันเว้นวันเเละติดตามผลเลือดด้วยถ้าลดจริงให้หยุดและกิน2อาทิตย์ต่อครั้งและค่อยๆลดลงจนเหลือเดือนละครั้งแต่คนที่เป็นโรคไตอยู่แล้วไม่ต้องกินนะไม่หายหรอกสมุนไพรมีทั้งคุณและโทษศึกษาให้ดีก่อนอย่าไปตามแฟชั่นเดี๋ยวทุกข์จะตามมา
# 93 คำยืนยันจากลูกค้าที่ใช้ดีคอนแทค
# 94 ดีคอนแทคได้จดลิขสิทธ์1เดียวของประเทศไทย
# 95 คลอโรฟิลล์คืออาหารเสริมไม่ใช่ยารักษาโรค!คลอโรฟิลล์คืออาหารเสริมไม่ใช่ยารักษาโรค!คลอโรฟิลล์คืออาหารเสริมไม่ใช่ยารักษาโรค!คลอโรฟิลล์คืออาหารเสริมไม่ใช่ยารักษาโรค!คลอโรฟิลล์คืออาหารเสริมไม่ใช่ยารักษาโรค!
# 96 อย่าลืมกินร้อนช้อนกลางล้างมือ
# 97 เหมือนทุเรียนเทศคับที่เอาใบไปต้มแก้มะเร็ง
# 98 ตัวขาวสวยขึ้นเอาน้ำยาบ้วนปากผสมกับน้ำส้มสายชูเห็นผลลัพธ์ที่ดีมาก
# 99 ก้อมัวแต่เอาเงินทุนวิจัยมะเร็งไปกินเหล้าแดงน้ำแข็งหลอดไงก่อเลยไม่รุว่าทุเรียนเทศมีประโยชน์รักษามะเร็งได้
# 100 แจกสูตรทำน้ำมะกรูดผสมโซดาสุดยอดน้ำสมุนไพรช่วยลดไขมันในเลือดได้ดีมากๆ
# 101 มะละกอดิบหั่นเป็นชิ้นๆต้มกันใบเตยก็ดีค่ะกินแทนน้ำเปล่ายิ่งดีลดความดันล้างลำใส้คือดีค่ะ
# 102 การดื่มน้ำทุเรียนเทศถ้ากินในปริมาณพอดีสามารถควบคุมระดับน้ำตาลในเลือดได้เเละในผู้ป่วยมะเร็งบางคนดีขึ้นจริงๆๆเเต่ถามหน่อยยาเคมีดีทุกคนจริงหรือร้อยละเท่าไหร่ที่รอดจากการบำบัดเคมี
# 103 ยาหมอแสงเป็นทางเลือกของผู้ป่วยมะเร็งหรือจะลองต้มใบทุเรียนเทศแห้งด้วยก็ได้
# 104 ทุเรียนน้ำ,ทุเรียนเทศทำลายอนุมูลอิสระที่ทำให้เกิดมะเร็ง(ป้องกันมะเร็ง)
# 105 ใบทุเรียนน้ำเขาว่าช่วยเรื่องมะเร็งได้
# 106 เกสรบัวหลวงกับมะตูมแห้งเอาไปต้มเป็นยาแก้อัลไซเมอร์
# 107 กระเทียมสุดยอดผักจริงๆตั้งแต่ค.แข็งยันโควิด
# 108 ไม่รู้จะเชื่อใครดีหมอก้อบอกว่าไม่ดีแต่ชาวบ้านทุกคนว่าดี.แต่เชื่อชาวบ้านมากกว่าหมอนะ.เพราะค่ารักษามะเร็งไม่ใช้บาทสองบาทนะแต่ละคนหมดเป็นล้านๆ.มีใบทุเรียนเทศออกมา.ทางโรงบาลเสียหายไปหลายล้าน.เชื่อชาวบ้านชัวร์
# 109 กินน้ำร้อนพอประมาณทำลายโควิดผสมกับขิงยิ่งดี
# 110 ใบทุเรียนเทศแห้งเอามาต้มกินมะเร็งหายค่ะตอนนี้ดังมากค่ะ
# 111 แชร์เก็บไว้เลย“ชามะละกอ”ช่วยล้างไขมันที่เกาะติดผนังลำไส้ได้ดีเยี่ยม
# 112 ทำไมไม่ลองเอาใบทุเรียนเทศมาต้มกินเห็นเขาหายจากมะเร็งระยะสุดท้ายกันเยอะอาจจะเป็นทางเลือกสุดท้ายที่ดีก็ได้นะครับ
# 113 เคยฟังคนภาคใต้เค้าเล่านานแล้วก่อนเรื่องนี้จะมาเป็นประเด็นว่ามีเยอะในภาคใต้แล้วคนเค้ารู้จักที่เป็นมะเร็งเค้ากินน้ำต้มใบทุเรียนน้ำแล้วหายนะ
# 114 ทุเรียนเทศช่วยรักษามะเร็งให้หายได้แล้วนะค่ะคุณยายลองไปหาชื้อให้น้องทานดูนะค่ะนำใบทุเรียนมาต้มกินก็ได้ค่ะหายไว้ๆนะค่ะ
# 115 คนทีเป็นมะเร็งเค้าให้กินทุเรียนเทศ...ช่วยได้หายก็หลายคนละ..เห็ดหลินจือแดงก็ดีเหมือนกันค่ะ
# 116 เจ้ลุกขึ้นมาต้มน้ำขิงข่าตะไคร้หอมแดงกระเทียมกินทุกวันน่ะต้านโควิดได้!
# 117 ใบทุเรียนเทศช่วยได้กินให้หายมะเร็งส่วนไตพังค่อยว่ากันอีกที
# 118 สูตรยาง่ายๆคับ.....ข้าวเย็นเหนือข้าวเย็นใต้ใบทุเรียนเทศ7ใบหญ้าขี้หนอนต้มกินแทนน้ำคับลุงกับตาผมเป็นมะเร็งระยะสุดท้ายหมอให้มานอนรอความตายที่บ้านแต่ทำกินแล้วจากทำไรไม่ได้เลยตอนนี้กลับมาแข็งแรงปกติแล้วไปตรวจดูเชื่อมะเร็งแห้งหมดจนหมอเหลือเชื่อลองดูนะคับยินดีให้คำปรึกษาฟรี
# 119 ญาติอยู่ภาคใต้กินรักษามะเร็งเต้านมตอนนี้ปกติดีไปให้เคมี๑ครั้งเกือบตายหมดแรงอ่อนเพลียกินน้ำชาทุเรียนน้ำเป็นปกติแล้ว
# 120 ดื่มวันละแก้วน้ำมะกรูดผสมโซดาช่วยลดไขมันได้ดีมาก
# 121 น้องพ่อเราเป็นมะเร็งสมองพอมากินใบทุเรียนเทศต้มอาการแกดีขึ้นเยอะเลยตอนนี้เดินไปทุ่งนาได้แล้วค่ะ
# 122 ให้คุณพ่อดื่มน้ำต้มใบทุเรียนเทศสิค่ะมีคนที่เป็นมะเร็งระยะสุดท้ายหายมาแล้วค่ะเรื่องจริง
# 123 สรุปคือใบทุเรียนเทศฆ่าเซลล์มะเร็งได้จริง(งานวิจัย)คนเขาเป็นมะเร็งเขาไม่มีทางเลือกอะไรมากรอหมอสกัดใบทุเรียนเทศกว่าจะได้เขาก็ตายพอดีครับหมอ
# 124 สมุนไพรกัญชาช่วยเสริมระบบประสาทอัลไซเมอร์ได้นะครับ
# 125 ของดีจากธรรมชาติ"ชามะละกอ"#ช่วยล้างไขมันที่เกาะติดผนังลำไส้ได้อย่างน่าอัศจรรย์!!
# 126 กลัวเสียหน้าเหรอหมอบอกมาตรงๆเลยว่าใบทุเรียนเทศมีส่วนยับยั้งและทำลายเซลมะเร็งได้
# 127 เพื่อนเป็นมะเร็งเต้านมก็หายนมก็ไม่ต้องผ่าตัดก็กินใบทุเรียนเทศนี้และค่ะแต่ต้องใบแห้ง
# 128 แต่ใบทุเรียนน้ำช่วยยับยั้งการเกิดมะเร็งได้ค่ะคนไม่เป็นมะเร็งก็กินได้กินแทนน้ำวันละ2~3แก้วก็ได้ค่ะและช่วยลดเบาหวาน,ความดันได้ค่ะเพราะว่าปัจจุบันพี่ก็ทาน
# 129 สุดอัศจรรย์ชาวเมืองแพร่ดื่มน้ำใบทุเรียนเทศเอาชนะมะเร็งระยะสุดท้าย

# %%
print(len(nondup_x_test), len(nondup_x_tags_test), len(nondup_y_test))
# Out:
# 4012 4012 4012

# %% [markdown]
# ## Data saving

# %%
def to_jsonl(
    _path: str,
    _X: List[str],
    _Y: List[str],
    _X_TAGS: List[str] = None
) -> None:
    samples = []
    if _X_TAGS is not None:
        for x, x_tags, y in zip(_X, _X_TAGS, _Y):
            samples.append({"Text": x, "Token Tags": x_tags, "Document Tag": y})
    else:
        for x, y in zip(_X, _Y):
            samples.append({"Text": x, "Document Tag": y})
            
    f = open(_path, 'w')
    for sample in samples:
        f.write("%s\n" % json.dumps(sample, ensure_ascii=False))
    f.close()

# %%
to_jsonl(
    "train_v1.jsonl",
    x_train, y_train
)

to_jsonl(
    "val_v1.jsonl",
    x_val, x_val
)

to_jsonl(
    "test_v1.jsonl",
    nondup_x_test, nondup_y_test, nondup_x_tags_test
)
